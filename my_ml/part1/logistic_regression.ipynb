# %%
# sigmoid function
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

x = np.linspace(-10,10,1000)
y = sigmoid(x)


ax = plt.gca()
ax.yaxis.grid(True)
plt.plot(x, y)
plt.axvline(0.0, color="black")

# %%
# Load dataset (create a small sample here)
import pandas as pd

data = {
    'Age': [22, 38, 26, 35, 35, 30],
    'Fare': [7.25, 71.2833, 7.925, 53.1, 8.05, 8.4583],
    'Pclass': [3, 1, 3, 1, 3, 3],
    'Sex': [0, 1, 1, 1, 0, 0],  # 0 = male, 1 = female
    'Survived': [0, 1, 1, 1, 0, 1]  # Target variable
}

df = pd.DataFrame(data)
X = df[['Age', 'Fare', 'Pclass', 'Sex']]  # Features
y = df['Survived']  # Target

# %%
df
# Out:
#    Age     Fare  Pclass  Sex  Survived
# 0   22   7.2500       3    0         0
# 1   38  71.2833       1    1         1
# 2   26   7.9250       3    1         1
# 3   35  53.1000       1    1         1
# 4   35   8.0500       3    0         0
# 5   30   8.4583       3    0         1

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train,  y_test = train_test_split(X, y, test_size=0.3, random_state=13)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
accuracy
# Out:
# 1.0

# %%
print(confusion_matrix(y_true=y_test, y_pred=y_pred))
# Out:
# [[2]]
# /home/davinci/GitHub/ml_practices/my_ml/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
