# %%
import pandas as pd

df = pd.read_csv("labeled_audio_features.csv")

df
# Out:
#                          Filename      File_ID  Spectral Centroid  \
# 0       HW1_Q5_810801072_Male.mp3  810801072.0        1190.596659
# 1    HW1.Q4j.810102087_female.mp3  810102087.0        1171.308126
# 2       HW1_Q3_810103262_male.mp3  810103262.0         962.185691
# 3     HW1_Q6_810600133_female.mp3  810600133.0        1394.939738
# 4       HW1_Q4_159403005_male.mp3  159403005.0        1039.728892
# ..                            ...          ...                ...
# 777     HW1_Q4_810102066_male.mp3  810102066.0        1300.428638
# 778     HW1_Q5_810103158_male.mp3  810103158.0        1092.733269
# 779     HW1_Q3_810103241_male.mp3  810103241.0        1393.106503
# 780   HW1_Q5_810100222_female.mp3  810100222.0        1032.301600
# 781     HW1-Q4-810801075-male.mp3  810801075.0        1304.984034
#
#      Spectral Bandwidth    Energy  Zero Crossing Rate     MFCC_1      MFCC_2  \
# 0            860.304927  0.018082            0.104027 -359.63320  115.977516
# 1            811.033637  0.042049            0.112831 -316.87390  124.256260
# 2            654.163178  0.073033            0.085811 -359.52280   82.929085
# 3            967.011634  0.040616            0.127732 -327.11000   77.596170
# 4            812.143556  0.046665            0.082820 -333.15906  112.615900
# ..                  ...       ...                 ...        ...         ...
# 777          940.624413  0.048195            0.123193 -296.99808  106.049280
# 778          757.320480  0.055939            0.104368 -332.57822  109.994675
# 779          902.804283  0.043221            0.136728 -354.21555   71.889366
# 780          738.187973  0.032410            0.096798 -385.17337   84.672740
# 781          894.928312  0.036779            0.123918 -307.74048  106.520950
#
#         MFCC_3     MFCC_4  ...  LogMel_127  LogMel_128  SpectralContrast_1  \
# 0   -82.352750 -10.930631  ...  -54.151608  -54.151608           24.698325
# 1   -83.462720  -7.142929  ...  -51.461970  -51.461970           27.021699
# 2   -38.925040  -2.616090  ...  -45.378930  -45.378930           26.264901
# 3   -66.509550   2.692544  ...  -46.676920  -46.676920           25.077578
# 4   -63.770080 -12.050776  ...  -48.922920  -48.922920           22.753146
# ..         ...        ...  ...         ...         ...                 ...
# 777 -81.401634  15.752192  ...  -49.962925  -49.962925           25.755823
# 778 -53.518814 -24.932074  ...  -47.142326  -47.142326           25.207737
# 779 -49.721287   2.120570  ...  -46.563490  -46.563490           26.820445
# 780 -25.377174  -8.708000  ...  -46.350407  -46.350407           23.926418
# 781 -89.114280 -14.088474  ...  -49.399815  -49.399815           26.440947
#
#      SpectralContrast_2  SpectralContrast_3  SpectralContrast_4  \
# 0             21.847045           17.482008           15.427769
# 1             18.915492           19.326000           16.883139
# 2             26.842508           26.764221           23.461604
# 3             21.766326           22.791543           20.759334
# 4             26.612855           20.602262           17.249414
# ..                  ...                 ...                 ...
# 777           23.254553           19.575685           17.371709
# 778           22.437619           20.206212           17.662317
# 779           21.588043           25.760321           22.174087
# 780           23.754249           24.528042           21.914459
# 781           21.834201           17.676599           16.877493
#
#      SpectralContrast_5  SpectralContrast_6  SpectralContrast_7  gender
# 0             18.416845           49.790245           18.596420    male
# 1             18.082144           44.165544           24.532498  female
# 2             25.222351           45.761993           22.058125    male
# 3             20.601537           50.721059           21.332874  female
# 4             19.077054           50.790446           19.150664    male
# ..                  ...                 ...                 ...     ...
# 777           17.263083           52.613275           19.480460    male
# 778           19.485465           49.553608           19.814700    male
# 779           26.787853           51.508139           22.561897    male
# 780           23.463030           47.133867           22.265805  female
# 781           16.586675           51.417239           18.147247    male
#
# [782 rows x 155 columns]

# %% [markdown]
# # Gender Classification

# %%
from sklearn.decomposition import PCA


# Select only the Log Mel Spectrogram features
logmel_features = [col for col in df.columns if col.startswith("LogMel_")]
X_logmel = df[logmel_features]

# Apply PCA to reduce dimensions (retain 95% variance)
pca = PCA(n_components=0.95)
X_pca = pca.fit_transform(X_logmel)

# Convert back to DataFrame
pca_columns = [f'PCA_{i+1}_LogMel' for i in range(X_pca.shape[1])]
df_pca = pd.DataFrame(X_pca, columns=pca_columns)

# Drop original Log Mel Spectrogram features and add new PCA features
df = df.drop(columns=logmel_features)
df = pd.concat([df, df_pca], axis=1)

print(f"Original Log Mel Features: {X_logmel.shape[1]}")
print(f"Reduced Log Mel Features: {X_pca.shape[1]}")
# Out:
# Original Log Mel Features: 128
# Reduced Log Mel Features: 9

# %%
df
# Out:
#                          Filename      File_ID  Spectral Centroid  \
# 0       HW1_Q5_810801072_Male.mp3  810801072.0        1190.596659
# 1    HW1.Q4j.810102087_female.mp3  810102087.0        1171.308126
# 2       HW1_Q3_810103262_male.mp3  810103262.0         962.185691
# 3     HW1_Q6_810600133_female.mp3  810600133.0        1394.939738
# 4       HW1_Q4_159403005_male.mp3  159403005.0        1039.728892
# ..                            ...          ...                ...
# 777     HW1_Q4_810102066_male.mp3  810102066.0        1300.428638
# 778     HW1_Q5_810103158_male.mp3  810103158.0        1092.733269
# 779     HW1_Q3_810103241_male.mp3  810103241.0        1393.106503
# 780   HW1_Q5_810100222_female.mp3  810100222.0        1032.301600
# 781     HW1-Q4-810801075-male.mp3  810801075.0        1304.984034
#
#      Spectral Bandwidth    Energy  Zero Crossing Rate     MFCC_1      MFCC_2  \
# 0            860.304927  0.018082            0.104027 -359.63320  115.977516
# 1            811.033637  0.042049            0.112831 -316.87390  124.256260
# 2            654.163178  0.073033            0.085811 -359.52280   82.929085
# 3            967.011634  0.040616            0.127732 -327.11000   77.596170
# 4            812.143556  0.046665            0.082820 -333.15906  112.615900
# ..                  ...       ...                 ...        ...         ...
# 777          940.624413  0.048195            0.123193 -296.99808  106.049280
# 778          757.320480  0.055939            0.104368 -332.57822  109.994675
# 779          902.804283  0.043221            0.136728 -354.21555   71.889366
# 780          738.187973  0.032410            0.096798 -385.17337   84.672740
# 781          894.928312  0.036779            0.123918 -307.74048  106.520950
#
#         MFCC_3     MFCC_4  ...  gender  PCA_1_LogMel  PCA_2_LogMel  \
# 0   -82.352750 -10.930631  ...    male     -2.607820    -33.795532
# 1   -83.462720  -7.142929  ...  female     40.799527    -25.561380
# 2   -38.925040  -2.616090  ...    male    -20.748574     23.295778
# 3   -66.509550   2.692544  ...  female     17.458803     15.217565
# 4   -63.770080 -12.050776  ...    male     17.748840     -9.532070
# ..         ...        ...  ...     ...           ...           ...
# 777 -81.401634  15.752192  ...    male     58.525567     -7.386061
# 778 -53.518814 -24.932074  ...    male     13.820304      0.096904
# 779 -49.721287   2.120570  ...    male    -14.377637     23.527056
# 780 -25.377174  -8.708000  ...  female    -48.420844     25.127838
# 781 -89.114280 -14.088474  ...    male     47.488838    -15.898340
#
#      PCA_3_LogMel  PCA_4_LogMel  PCA_5_LogMel  PCA_6_LogMel  PCA_7_LogMel  \
# 0       -2.442312      7.253254      2.051352      4.490312      5.228817
# 1       -8.029452     -6.236530     -7.681814      5.692460      8.410901
# 2        2.369420      8.366372      6.857870      8.146525     -7.794500
# 3       21.063499      2.726795    -13.471037     -5.313799      8.142098
# 4      -11.866897      3.523785      5.342845      4.370928      1.109144
# ..            ...           ...           ...           ...           ...
# 777     15.039841    -15.761263      8.329770      0.505218      3.820365
# 778    -20.735485     14.475575      2.020939     -8.561323     -3.925206
# 779     19.196173      8.823776     -0.476459     -7.430007      3.937373
# 780     -9.025960     -1.920097     -6.467009      4.735607      9.493908
# 781      5.190288      7.453747    -12.704706    -11.255981     -8.833851
#
#      PCA_8_LogMel  PCA_9_LogMel
# 0        7.312095     -1.653790
# 1       13.930295      8.509958
# 2       -4.296828      2.678711
# 3        2.580769      0.545889
# 4       -0.873636      1.932672
# ..            ...           ...
# 777     -6.147370     -0.039656
# 778     -4.570513     -6.187480
# 779    -13.748444      0.309889
# 780     -3.967990      2.385022
# 781      4.863176     -4.379680
#
# [782 rows x 36 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np


# Selecting 32 numeric features for training
X = df.drop(columns=["gender", "File_ID", "Filename"])

# Normalize the data
scaler = StandardScaler()
X = scaler.fit_transform(X)

target_column = "gender"  # Assuming gender is the target column
y = df[target_column]

# Encode target variable
y = (y == 'male').astype(int)  # Convert 'male' to 1 and 'female' to 0


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=42)

# %% [markdown]
# ### >> using Neural Networks

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Build the neural network model
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(33,)),
    layers.Dense(32, activation='relu'),
    layers.Dense(1, activation='sigmoid')  # Binary classification
])
# Out:
# 2025-02-04 00:35:50.830262: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-04 00:35:50.830833: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-04 00:35:50.833961: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-04 00:35:50.841430: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738616750.854587   73155 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738616750.858343   73155 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-04 00:35:50.871290: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/davinci/GitHub/JANJAN/ml_practices/university/ml/final project/env/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-02-04 00:35:52.210370: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

# Save the trained model
model.save("gender_classification_model.h5")
# Out:
# Epoch 1/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7456 - loss: 0.5299 - val_accuracy: 0.8163 - val_loss: 0.4137
# Epoch 2/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8479 - loss: 0.3568 - val_accuracy: 0.8827 - val_loss: 0.3086
# Epoch 3/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9287 - loss: 0.2277 - val_accuracy: 0.9184 - val_loss: 0.2390
# Epoch 4/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9504 - loss: 0.1734 - val_accuracy: 0.9439 - val_loss: 0.1919
# Epoch 5/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9783 - loss: 0.1102 - val_accuracy: 0.9388 - val_loss: 0.1595
# Epoch 6/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9753 - loss: 0.0894 - val_accuracy: 0.9439 - val_loss: 0.1361
# Epoch 7/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9883 - loss: 0.0583 - val_accuracy: 0.9388 - val_loss: 0.1295
# Epoch 8/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9875 - loss: 0.0534 - val_accuracy: 0.9439 - val_loss: 0.1150
# Epoch 9/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9902 - loss: 0.0547 - val_accuracy: 0.9439 - val_loss: 0.1047
# Epoch 10/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9966 - loss: 0.0347 - val_accuracy: 0.9490 - val_loss: 0.1031
# Epoch 11/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9874 - loss: 0.0408 - val_accuracy: 0.9490 - val_loss: 0.0969
# Epoch 12/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9931 - loss: 0.0277 - val_accuracy: 0.9643 - val_loss: 0.0866
# Epoch 13/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9947 - loss: 0.0239 - val_accuracy: 0.9694 - val_loss: 0.0833
# Epoch 14/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9944 - loss: 0.0175 - val_accuracy: 0.9694 - val_loss: 0.0824
# Epoch 15/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9938 - loss: 0.0197 - val_accuracy: 0.9694 - val_loss: 0.0812
# Epoch 16/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9997 - loss: 0.0109 - val_accuracy: 0.9694 - val_loss: 0.0762
# Epoch 17/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9993 - loss: 0.0107 - val_accuracy: 0.9643 - val_loss: 0.0767
# Epoch 18/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.9643 - val_loss: 0.0745
# Epoch 19/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9643 - val_loss: 0.0754
# Epoch 20/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9745 - val_loss: 0.0704
# Epoch 21/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.9694 - val_loss: 0.0706
# Epoch 22/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.9694 - val_loss: 0.0704
# Epoch 23/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9694 - val_loss: 0.0701
# Epoch 24/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9694 - val_loss: 0.0682
# Epoch 25/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9694 - val_loss: 0.0700
# Epoch 26/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9694 - val_loss: 0.0675
# Epoch 27/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9694 - val_loss: 0.0711
# Epoch 28/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9694 - val_loss: 0.0686
# Epoch 29/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9694 - val_loss: 0.0696
# Epoch 30/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9694 - val_loss: 0.0701
# Epoch 31/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9694 - val_loss: 0.0677
# Epoch 32/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9694 - val_loss: 0.0698
# Epoch 33/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9694 - val_loss: 0.0690
# Epoch 34/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9694 - val_loss: 0.0685
# Epoch 35/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9694 - val_loss: 0.0670
# Epoch 36/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9694 - val_loss: 0.0695
# Epoch 37/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9694 - val_loss: 0.0680
# Epoch 38/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9694 - val_loss: 0.0665
# Epoch 39/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9694 - val_loss: 0.0670
# Epoch 40/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9694 - val_loss: 0.0689
# Epoch 41/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9694 - val_loss: 0.0689
# Epoch 42/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9694 - val_loss: 0.0691
# Epoch 43/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9694 - val_loss: 0.0693
# Epoch 44/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9694 - val_loss: 0.0696
# Epoch 45/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.4692e-04 - val_accuracy: 0.9694 - val_loss: 0.0695
# Epoch 46/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.3403e-04 - val_accuracy: 0.9694 - val_loss: 0.0694
# Epoch 47/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.1795e-04 - val_accuracy: 0.9694 - val_loss: 0.0697
# Epoch 48/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.6532e-04 - val_accuracy: 0.9694 - val_loss: 0.0699
# Epoch 49/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.8367e-04 - val_accuracy: 0.9694 - val_loss: 0.0696
# Epoch 50/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.5711e-04 - val_accuracy: 0.9694 - val_loss: 0.0700
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import matplotlib.pyplot as plt


# Plot training history
plt.figure(figsize=(12, 5))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.show()
