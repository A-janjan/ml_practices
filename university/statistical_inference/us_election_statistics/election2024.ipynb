# %% [markdown]
# # 2024 US Presidential Election

# %%
! wget https://projects.fivethirtyeight.com/polls-page/data/generic_ballot_polls.csv

# %%
import pandas as pd

df = pd.read_csv("generic_ballot_polls.csv")

# %%
df.shape
# Out:
# (735, 44)

# %%
df.iloc[:, :10]
# Out:
#      poll_id  pollster_id               pollster sponsor_ids        sponsors  \
# 0      89371         1705  John Zogby Strategies         NaN             NaN
# 1      89350         1205                 Marist    373,2166  NPR | PBS News
# 2      89251         1102                Emerson         NaN             NaN
# 3      89252         1292               Hart/POS         132        NBC News
# 4      89366         1416                HarrisX        2097          Forbes
# ..       ...          ...                    ...         ...             ...
# 730    83698         1189        Morning Consult         NaN             NaN
# 731    83699         1189        Morning Consult         NaN             NaN
# 732    83700         1189        Morning Consult         NaN             NaN
# 733    83701         1189        Morning Consult         NaN             NaN
# 734    83702         1189        Morning Consult         NaN             NaN
#
#                                           display_name  pollster_rating_id  \
# 0                                John Zogby Strategies                 583
# 1                                       Marist College                 183
# 2                                      Emerson College                  88
# 3    Hart Research Associates/Public Opinion Strate...                 221
# 4                                              HarrisX                 133
# ..                                                 ...                 ...
# 730                                    Morning Consult                 218
# 731                                    Morning Consult                 218
# 732                                    Morning Consult                 218
# 733                                    Morning Consult                 218
# 734                                    Morning Consult                 218
#
#                                   pollster_rating_name  numeric_grade  \
# 0                                John Zogby Strategies            1.8
# 1                                       Marist College            2.9
# 2                                      Emerson College            2.9
# 3    Hart Research Associates/Public Opinion Strate...            2.6
# 4                          Harris Insights & Analytics            1.5
# ..                                                 ...            ...
# 730                                    Morning Consult            1.9
# 731                                    Morning Consult            1.9
# 732                                    Morning Consult            1.9
# 733                                    Morning Consult            1.9
# 734                                    Morning Consult            1.9
#
#      pollscore
# 0          0.0
# 1         -0.9
# 2         -1.1
# 3         -0.7
# 4         -0.1
# ..         ...
# 730       -0.3
# 731       -0.3
# 732       -0.3
# 733       -0.3
# 734       -0.3
#
# [735 rows x 10 columns]

# %%
df.iloc[:, 10:20]
# Out:
#                              methodology  transparency_score  state  \
# 0                           Online Panel                 5.0    NaN
# 1    Live Phone/Online Panel/Text-to-Web                 9.0    NaN
# 2           IVR/Online Panel/Text-to-Web                 7.0    NaN
# 3                             Live Phone                 4.0    NaN
# 4                           Online Panel                 6.0    NaN
# ..                                   ...                 ...    ...
# 730                         Online Panel                 NaN    NaN
# 731                         Online Panel                 NaN    NaN
# 732                         Online Panel                 NaN    NaN
# 733                         Online Panel                 NaN    NaN
# 734                         Online Panel                 NaN    NaN
#
#     start_date  end_date  sponsor_candidate_id  sponsor_candidate  \
# 0      11/2/24   11/3/24                   NaN                NaN
# 1     10/31/24   11/2/24                   NaN                NaN
# 2     10/30/24   11/2/24                   NaN                NaN
# 3     10/30/24   11/2/24                   NaN                NaN
# 4     10/30/24   11/2/24                   NaN                NaN
# ..         ...       ...                   ...                ...
# 730   11/13/22  11/15/22                   NaN                NaN
# 731   11/12/22  11/14/22                   NaN                NaN
# 732   11/11/22  11/13/22                   NaN                NaN
# 733   11/10/22  11/12/22                   NaN                NaN
# 734    11/9/22  11/11/22                   NaN                NaN
#
#      sponsor_candidate_party  question_id  sample_size
# 0                        NaN       216447       1005.0
# 1                        NaN       216297       1297.0
# 2                        NaN       215928       1000.0
# 3                        NaN       215929       1000.0
# 4                        NaN       216414       4520.0
# ..                       ...          ...          ...
# 730                      NaN       179305       7439.0
# 731                      NaN       179306       7439.0
# 732                      NaN       179307       7439.0
# 733                      NaN       179308       7439.0
# 734                      NaN       179309       7439.0
#
# [735 rows x 10 columns]

# %%
df.iloc[:,20:30]
# Out:
#     population subpopulation population_full tracking     created_at notes  \
# 0           lv           NaN              lv      NaN  11/4/24 18:29   NaN
# 1           lv           NaN              lv      NaN  11/4/24 12:25   NaN
# 2           lv           NaN              lv      NaN  11/3/24 09:32   NaN
# 3           rv           NaN              rv      NaN  11/3/24 09:32   NaN
# 4           rv           NaN              rv      NaN  11/4/24 16:23   NaN
# ..         ...           ...             ...      ...            ...   ...
# 730         rv           NaN              rv     True  8/17/23 11:30   NaN
# 731         rv           NaN              rv     True  8/17/23 11:30   NaN
# 732         rv           NaN              rv     True  8/17/23 11:30   NaN
# 733         rv           NaN              rv     True  8/17/23 11:30   NaN
# 734         rv           NaN              rv     True  8/17/23 11:30   NaN
#
#                                                    url  \
# 0    https://johnzogbystrategies.com/harris-leads-t...
# 1    https://maristpoll.marist.edu/polls/u-s-presid...
# 2    https://emersoncollegepolling.com/november-202...
# 3    https://www.nbcnews.com/politics/2024-election...
# 4    https://www.forbes.com/sites/saradorn/2024/11/...
# ..                                                 ...
# 730  https://pro.morningconsult.com/analysis/2024-g...
# 731  https://pro.morningconsult.com/analysis/2024-g...
# 732  https://pro.morningconsult.com/analysis/2024-g...
# 733  https://pro.morningconsult.com/analysis/2024-g...
# 734  https://pro.morningconsult.com/analysis/2024-g...
#
#                                            url_article  \
# 0    https://johnzogbystrategies.com/harris-leads-t...
# 1    https://maristpoll.marist.edu/polls/u-s-presid...
# 2    https://emersoncollegepolling.com/november-202...
# 3    https://www.nbcnews.com/politics/2024-election...
# 4    https://www.forbes.com/sites/saradorn/2024/11/...
# ..                                                 ...
# 730  https://pro.morningconsult.com/analysis/2024-g...
# 731  https://pro.morningconsult.com/analysis/2024-g...
# 732  https://pro.morningconsult.com/analysis/2024-g...
# 733  https://pro.morningconsult.com/analysis/2024-g...
# 734  https://pro.morningconsult.com/analysis/2024-g...
#
#                                            url_topline  \
# 0    https://johnzogbystrategies.com/wp-content/upl...
# 1                                                  NaN
# 2                                                  NaN
# 3    https://s3.documentcloud.org/documents/2526523...
# 4                                                  NaN
# ..                                                 ...
# 730                                                NaN
# 731                                                NaN
# 732                                                NaN
# 733                                                NaN
# 734                                                NaN
#
#                                           url_crosstab
# 0                                                  NaN
# 1    https://view.officeapps.live.com/op/view.aspx?...
# 2    https://docs.google.com/spreadsheets/d/1zSMg6l...
# 3                                                  NaN
# 4    https://elections.harrisx.com/public/HX_Forbes...
# ..                                                 ...
# 730                                                NaN
# 731                                                NaN
# 732                                                NaN
# 733                                                NaN
# 734                                                NaN
#
# [735 rows x 10 columns]

# %%
df.iloc[:, 30:]
# Out:
#      source internal partisan  race_id  cycle office_type  seat_number  \
# 0       NaN      NaN      NaN     9549   2024  U.S. House          NaN
# 1       NaN    False      NaN     9549   2024  U.S. House          NaN
# 2       NaN      NaN      NaN     9549   2024  U.S. House          NaN
# 3       NaN      NaN      NaN     9549   2024  U.S. House          NaN
# 4       NaN      NaN      NaN     9549   2024  U.S. House          NaN
# ..      ...      ...      ...      ...    ...         ...          ...
# 730     NaN      NaN      NaN     9549   2024  U.S. House          NaN
# 731     NaN      NaN      NaN     9549   2024  U.S. House          NaN
# 732     NaN      NaN      NaN     9549   2024  U.S. House          NaN
# 733     NaN      NaN      NaN     9549   2024  U.S. House          NaN
# 734     NaN      NaN      NaN     9549   2024  U.S. House          NaN
#
#     seat_name election_date    stage  nationwide_batch   dem   rep  ind
# 0     Generic       11/5/24  general             False  46.1  44.7  NaN
# 1     Generic       11/5/24  general             False  50.0  48.0  NaN
# 2     Generic       11/5/24  general             False  48.2  47.1  NaN
# 3     Generic       11/5/24  general             False  47.0  46.0  NaN
# 4     Generic       11/5/24  general             False  43.0  42.0  NaN
# ..        ...           ...      ...               ...   ...   ...  ...
# 730   Generic       11/5/24  general             False  47.0  44.0  NaN
# 731   Generic       11/5/24  general             False  48.0  44.0  NaN
# 732   Generic       11/5/24  general             False  48.0  44.0  NaN
# 733   Generic       11/5/24  general             False  48.0  44.0  NaN
# 734   Generic       11/5/24  general             False  47.0  44.0  NaN
#
# [735 rows x 14 columns]

# %%
# pruninig dataset

df = df[["start_date", "sample_size", "dem", "rep"]]

df
# Out:
#     start_date  sample_size   dem   rep
# 0      11/2/24       1005.0  46.1  44.7
# 1     10/31/24       1297.0  50.0  48.0
# 2     10/30/24       1000.0  48.2  47.1
# 3     10/30/24       1000.0  47.0  46.0
# 4     10/30/24       4520.0  43.0  42.0
# ..         ...          ...   ...   ...
# 730   11/13/22       7439.0  47.0  44.0
# 731   11/12/22       7439.0  48.0  44.0
# 732   11/11/22       7439.0  48.0  44.0
# 733   11/10/22       7439.0  48.0  44.0
# 734    11/9/22       7439.0  47.0  44.0
#
# [735 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# start_date     0
# sample_size    8
# dem            0
# rep            0
# dtype: int64

# %%
df = df.dropna(subset=['sample_size'])

df.shape
# Out:
# (727, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 727 entries, 0 to 734
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   start_date   727 non-null    object
#  1   sample_size  727 non-null    float64
#  2   dem          727 non-null    float64
#  3   rep          727 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 28.4+ KB

# %%
average = pd.DataFrame(df[['dem', 'rep']].mean())

print(average)
# Out:
#              0
# dem  44.798432
# rep  44.014856

# %%
std = pd.DataFrame(df[['dem', 'rep']].std())

std
# Out:
#             0
# dem  2.200296
# rep  2.382905

# %%
poll_avg=pd.concat([average,std],axis=1)
poll_avg.columns=['Average','STD']
poll_avg
# Out:
#        Average       STD
# dem  44.798432  2.200296
# rep  44.014856  2.382905

# %% [markdown]
# # Question 1

# %% [markdown]
# please see my calculation on paper for more detail about following formulas

# %%
N = int(sum(df["sample_size"]))
N
# Out:
# 2686859

# %%
p_hat = float(average.loc['dem'])

# %%
p_hat /= 100

p_hat
# Out:
# 0.44798431911966985

# %%
import numpy as np

min_of_interval = p_hat - 1.96 * np.sqrt( ( (1-p_hat) * p_hat ) / N )

min_of_interval
# Out:
# 0.4473896974297283

# %%
max_of_interval = p_hat + 1.96 * np.sqrt(((1-p_hat)*p_hat)/N)

max_of_interval
# Out:
# 0.4485789408096114

# %%
print(f"95% confidence interval: ({min_of_interval}, {max_of_interval})")
# Out:
# 95% confidence interval: (0.4473896974297283, 0.4485789408096114)

# %% [markdown]
# # we can also consider another value for N , for example number of records

# %%
N = len(df)

N
# Out:
# 727

# %%
import numpy as np

min_of_interval = p_hat - 1.96 * np.sqrt( ( (1-p_hat) * p_hat ) / N )

min_of_interval
# Out:
# 0.41183534477380196

# %%
max_of_interval = p_hat + 1.96 * np.sqrt(((1-p_hat)*p_hat)/N)

max_of_interval
# Out:
# 0.48413329346553774

# %%
print(f"95% confidence interval: ({min_of_interval}, {max_of_interval})")
# Out:
# 95% confidence interval: (0.41183534477380196, 0.48413329346553774)

# %% [markdown]
# # Question 2

# %%
import numpy as np

p_true = 0.44  # True population proportion
N = 30         # Sample size
iterations = 10**5  # Number of iterations for the simulation
Z = 1.96       # Z-score for 95% confidence interval


captures = 0  # Counter for intervals capturing the true proportion
for _ in range(iterations):
    # Generate sample of size N
    sample = np.random.binomial(1, p_true, N)
    p_hat = sample.mean()  # Sample proportion

    # Calculate the confidence interval for p_hat
    margin_of_error = Z * np.sqrt((p_hat * (1 - p_hat)) / N)
    ci_lower = p_hat - margin_of_error
    ci_upper = p_hat + margin_of_error

    # Check if the true proportion p is within the confidence interval
    if ci_lower <= p_true <= ci_upper:
        captures += 1

# Calculate the percentage of intervals that capture the true proportion
capture_rate = captures / iterations
capture_rate
# Out:
# 0.93524

# %% [markdown]
# # Question 3

# %%
df
# Out:
#     start_date  sample_size   dem   rep
# 0      11/2/24       1005.0  46.1  44.7
# 1     10/31/24       1297.0  50.0  48.0
# 2     10/30/24       1000.0  48.2  47.1
# 3     10/30/24       1000.0  47.0  46.0
# 4     10/30/24       4520.0  43.0  42.0
# ..         ...          ...   ...   ...
# 730   11/13/22       7439.0  47.0  44.0
# 731   11/12/22       7439.0  48.0  44.0
# 732   11/11/22       7439.0  48.0  44.0
# 733   11/10/22       7439.0  48.0  44.0
# 734    11/9/22       7439.0  47.0  44.0
#
# [727 rows x 4 columns]

# %% [markdown]
# # Question 4

# %%
import matplotlib.pyplot as plt
import pandas as pd

df['start_date'] = pd.to_datetime(df['start_date'])
df.set_index('start_date', inplace=True)

# Calculate a rolling average for Trump and Clinton support (adjust window as needed)
df['rep'] = df['rep'].rolling(window=10, min_periods=1).mean()
df['dem'] = df['dem'].rolling(window=10, min_periods=1).mean()

# Plot the poll results with smooth trend lines
plt.figure(figsize=(12, 6))

# Plot original data points
plt.plot(df.index, df['rep'], label="Trump Support", color='red', alpha=0.6, linewidth=1.5)
plt.plot(df.index, df['dem'], label="Harris Support", color='blue', alpha=0.6, linewidth=1.5)

# Plot the rolling average trend lines
plt.plot(df.index, df['rep'], label="Trump Trend", color='red', linestyle='--', linewidth=2)
plt.plot(df.index, df['dem'], label="Harris Trend", color='blue', linestyle='--', linewidth=2)

# Title and labels
plt.title("Poll Results: Support Percentages for Trump and Harris", fontsize=16)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Support Percentage", fontsize=12)

# Show legend
plt.legend()

# Format x-axis with date labels for readability
plt.xticks(rotation=45)
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-31-4552a46bdf86>:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['start_date'] = pd.to_datetime(df['start_date'])
# <ipython-input-31-4552a46bdf86>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_date'] = pd.to_datetime(df['start_date'])
# <ipython-input-31-4552a46bdf86>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rep'] = df['rep'].rolling(window=10, min_periods=1).mean()
# <ipython-input-31-4552a46bdf86>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dem'] = df['dem'].rolling(window=10, min_periods=1).mean()

# %% [markdown]
# # Question 5

# %%
# total number of voters

total_voters = int(sum(df["sample_size"]))

total_voters
# Out:
# 2686859

# %% [markdown]
# # Question 6

# %%
average
# Out:
#              0
# dem  44.798432
# rep  44.014856

# %% [markdown]
# # Question 7

# %%
############## Trump ###############

p_hat = float(average.iloc[1] / 100)

N = total_voters

min_of_interval = p_hat - 1.96 * np.sqrt( ( (1-p_hat) * p_hat ) / N )

max_of_interval = p_hat + 1.96 * np.sqrt( ( (1-p_hat) * p_hat ) / N )

# %%
print(f"95% confidence interval for Trump: ({min_of_interval}, {max_of_interval})")
# Out:
# 95% confidence interval for Trump: (0.4395549888076644, 0.4407421226091168)

# %%
############## Harris ###############

p_hat = float(average.iloc[0] / 100)

N = total_voters

min_of_interval = p_hat - 1.96 * np.sqrt( ( (1-p_hat) * p_hat ) / N )

max_of_interval = p_hat + 1.96 * np.sqrt( ( (1-p_hat) * p_hat ) / N )

# %%
print(f"95% confidence interval for Harris: ({min_of_interval}, {max_of_interval})")
# Out:
# 95% confidence interval for Harris: (0.4473896974297283, 0.4485789408096114)

# %% [markdown]
# # Question 8

# %%
# Harris p_hat
p_hat = float(average.iloc[0] / 100)
N = total_voters

SE = np.sqrt( ( p_hat * (1-p_hat) ) / N )

# %%
# CI for 2d
upper_ci = ( 2 * p_hat - 1 ) + 1.96 * 2 * SE

lower_ci = ( 2 * p_hat - 1 ) - 1.96 * 2 * SE

print(f"95% confidence interval for 2d: ({lower_ci}, {upper_ci})")
# Out:
# 95% confidence interval for 2d: (-0.10522060514054343, -0.10284211838077717)

# %%
# Re-importing necessary libraries due to environment reset
from scipy import stats

# Calculate the sample mean (midpoint of CI) and margin of error (half of the CI width)
mean_d = (lower_ci + upper_ci) / 2
margin_of_error = (upper_ci - lower_ci) / 2

# Standard error based on 95% CI (z = 1.96 for 95% confidence)
z_score = 1.96
standard_error = margin_of_error / z_score

# Calculate the t-statistic for H0: d = 0
t_statistic = mean_d / standard_error

# Calculate the p-value for a two-tailed test
p_value = 2 * (1 - stats.norm.cdf(abs(t_statistic)))

# Display results
mean_d, standard_error, t_statistic, p_value
# Out:
# (-0.1040313617606603, 0.0006067568264709855, -171.4547858748071, 0.0)

# %% [markdown]
# Since the p-value is extremely close to zero, we strongly reject the null hypothesis.
#
# This indicates that the spread 𝑑 is significantly different from zero.
